# %% [markdown]
# # 02 — Blocking Analysis
#
# Evaluate candidate generation: recall ceiling versus candidate-set size.

# %% [markdown]
# ## Blocking keys

# %% [markdown]
# ## Recall vs. candidates per S1 entity

# %% [markdown]
# ## Reduction ratio

# %% [markdown]
# ## Missed true matches
