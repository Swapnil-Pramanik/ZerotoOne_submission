# %% [markdown]
# # 03 — Matching Error Analysis
#
# Inspect model errors on the validation split and tune the decision threshold for F0.5.

# %% [markdown]
# ## Validation F0.5

# %% [markdown]
# ## Threshold sweep

# %% [markdown]
# ## False positives (wrong merges)

# %% [markdown]
# ## False negatives (missed matches)

# %% [markdown]
# ## Singleton performance

# %% [markdown]
# ## Per-country breakdown
